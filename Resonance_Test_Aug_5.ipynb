#   1293.375      1293.3828125  1293.390625   1293.3984375  1293.40625
#   1293.4140625  1293.421875   1293.4296875  1293.4375     1293.4453125
#   1293.453125   1293.4609375  1293.46875    1293.4765625  1293.484375
#   1293.4921875  1293.5        1293.5078125  1293.515625   1293.5234375
#   1293.53125    1293.5390625  1293.546875   1293.5546875  1293.5625
#   1293.5703125  1293.578125   1293.5859375  1293.59375    1293.6015625
#   1293.609375   1293.6171875  1293.625      1293.6328125  1293.640625
#   1293.6484375  1293.65625    1293.6640625  1293.671875   1293.6796875
#   1293.6875     1293.6953125  1293.703125   1293.7109375  1293.71875
#   1293.7265625  1293.734375   1293.7421875  1293.75       1293.7578125
#   1293.765625   1293.7734375  1293.78125    1293.7890625  1293.796875
# ...

# %%
plot(x,y)
dx = np. gradient(x)
gradient = np.gradient(y,dx)
gradient_ave = np.average(gradient)
plot(x,y)
print gradient_ave
plot([x[0],x[79]],[y[0],y[79]], color = 'red')

x_diff = abs ( x[79]-x[0])
y_diff = abs ( y[79]-y[0])
print y_diff/x_diff
# Out:
# 0.252889584
# 0.232478298734

# %%
import numpy as np
x=np.linspace(0,3.9*np.pi,100)
y=np.sin(x)

champ=38
m = 5
noise = 5
away= 3*noise

y[5]=y[5] + 0.3
y[9]=y[9] + 0.1
y[10]=y[10] - 0.1
y[15]=y[15] - 0.1
y[14]=y[14] - 0.3
y[16]=y[16] + 0.1
y[18]=y[18] + 0.2
y[28]=y[28] + 0.2
y[29]=y[29] - 0.1


y[45]=y[45] + 0.3
y[47]=y[47] - 0.3
y[50]=y[50] + 0.1
y[55]=y[55] + 0.3
y[63]=y[63] - 0.3
y[95]=y[95] + 0.1
y[85]=y[85] - 0.1
y[68]=y[68] + 0.2
y[95]=y[95] - 0.1
y[78]=y[78] + 0.3


scatter (x,y)
plot (x,y)


########################################################
index_to_the_left=[]
index_to_the_right=[]
center = champ
scatter (x[center],y[center], color ="red",s =80)
scatter (x[99],y[99], color ="orange",s =80)
start_center = center
while center + away   != len(y):
    dx = np. gradient(x[center : center + away])
    right_gradient = np.gradient(y[center : center + away],dx)
    right_gradient_ave = np.average(right_gradient)
    if right_gradient_ave < 0:
        print right_gradient_ave
        scatter(x[center + away/2],y[center + away/2], color = "green",s =80)
        index_to_the_left = (center + away/2) - start_center 
        break
    center = center + 1
    
center = champ 
scatter (x[center],y[center], color ="red",s =80)
scatter (x[0],y[0], color ="orange",s =80)
start_center = center
while center - away != 0:
    dx = np. gradient(x[ center - away: center])
    left_gradient = np.gradient(y[center - away:center],dx)
    left_gradient_ave = np.average(left_gradient)
    print left_gradient_ave
    if left_gradient_ave > 0: 
        print left_gradient_ave
        scatter(x[center - away/2],y[center -away/2], color = "green",s =80)
        #print x[center],y[center]
        index_to_the_right = start_center - (center - away/2)
        #print index_to_the_right
        break
    center = center - 1
print index_to_the_left, index_to_the_right

#right_gradient_ave = np.average(right_gradient)

#dx = np. gradient(x[center - away : center])
#left_gradient = np.gradient(y[center - away : center],dx)
#left_gradient_ave = np.average(left_gradient)


#if left_gradient_ave < 0 and right_gradient_ave > 0:
#    print "It is a minima"
#if left_gradient_ave > 0 and right_gradient_ave < 0:
#    print "It is a maxima"
#if left_gradient_ave == 0 and right_gradient_ave == 0:
#    print "It's flat"
#elif left_gradient_ave == 0 or right_gradient_ave == 0: 
#    print " It's not continuos"
# Out:
# -0.140286893486
# -0.72944772251
# -0.781737595198
# -0.822069285402
# -0.849825842222
# -0.864582675653
# -1.02771753218
# -0.80052871752
# -0.883477223135
# -0.819065687615
# -0.36546218237
# -0.762385373994
# -0.610204161989
# -0.529490442146
# -0.359875405624
# -0.452858497681
# -0.217355309629
# -0.139718727981
# -0.0330109657833
# -0.22207128518
# 0.422684653354
# 0.422684653354
# 24 26

# %%
flat = 1.2
m = 5                                               # This is the number of points to the left or right of centre
noise = 5                                           # This is how many points "high " you want the noise to be

import numpy as np
locmins=[[1220.9765625, -33.121995195625942, 2493], [1221.25, -32.85327867766128, 2528], [1226.171875, -34.453947107120086, 3158], [1227.46875, -34.225530811706584, 3324], [1227.484375, -35.350331471926445, 3326], [1236.9609375, -34.976704349295019, 4539], [1248.1484375, -35.023000817700321, 5971], [1251.75, -32.907955099285388, 6432], [1252.0859375, -32.199989169280066, 6475], [1263.9765625, -31.080325027314064, 7997], [1263.9921875, -30.886873573666467, 7999], [1268.703125, -33.611114813186347, 8602], [1275.3984375, -29.647643931344927, 9459], [1283.171875, -30.436153310270036, 10454], [1288.8203125, -27.69735889836042, 11177], [1291.328125, -35.6302226430928, 11498], [1297.7265625, -27.778834415700974, 12317], [1304.0390625, -26.433675233189149, 13125], [1305.1015625, -34.546847150281295, 13261], [1310.0625, -27.825445992119281, 13896], [1318.4921875, -33.548219141837301, 14975], [1318.5078125, -33.50169364213771, 14977], [1346.328125, -25.220338484613105, 18538], [1352.125, -28.560465125431016, 19280], [1356.1640625, -27.735589825853133, 19797], [1359.65625, -25.819248091769296, 20244], [1368.8828125, -25.140455880149997, 21425], [1372.59375, -29.376220655061516, 21900], [1385.734375, -25.577992155552639, 23582], [1387.3984375, -30.144288527429595, 23795], [1389.4453125, -24.854758890762984, 24057], [1402.1328125, -28.497460882383493, 25681], [1402.328125, -35.177678168547985, 25706], [1418.140625, -25.734894045377956, 27730], [1426.3515625, -31.553683567834948, 28781], [1434.9453125, -32.142189890940799, 29881], [1437.9453125, -30.134753884920059, 30265], [1444.921875, -34.861777454182409, 31158], [1452.6015625, -31.475826432171704, 32141]]
for i in range(1,len( locmins)):
    after = locmins[i][2]
    before = locmins[i-1][2]
    diff = abs(after - before)
    away = m + noise
    
    print after, before, diff
    if diff < away :
        print " This two point will repeat", locmins[i], locmins[i-1]
        y_after = locmins[i]
        y_before = locmins[i-1]
        if y_after < y_before :
            locmins[i-1] = [0,0,0]
        if y_after > y_before :
            locmins[i] = [0,0,0]
print '\n'            
print locmins
print len(locmins),'\n'
while [0,0,0] in locmins: locmins.remove([0,0,0])    
print locmins
print len(locmins)
# Out:
# 2528 2493 35
# 3158 2528 630
# 3324 3158 166
# 3326 3324 2
#  This two point will repeat [1227.484375, -35.350331471926445, 3326] [1227.46875, -34.225530811706584, 3324]
# 4539 0 4539
# 5971 4539 1432
# 6432 5971 461
# 6475 6432 43
# 7997 6475 1522
# 7999 7997 2
#  This two point will repeat [1263.9921875, -30.886873573666467, 7999] [1263.9765625, -31.080325027314064, 7997]
# 8602 0 8602
# 9459 8602 857
# 10454 9459 995
# 11177 10454 723
# 11498 11177 321
# 12317 11498 819
# 13125 12317 808
# 13261 13125 136
# 13896 13261 635
# 14975 13896 1079
# 14977 14975 2
#  This two point will repeat [1318.5078125, -33.50169364213771, 14977] [1318.4921875, -33.5482191418373, 14975]
# 18538 0 18538
# 19280 18538 742
# 19797 19280 517
# 20244 19797 447
# 21425 20244 1181
# 21900 21425 475
# 23582 21900 1682
# 23795 23582 213
# 24057 23795 262
# 25681 24057 1624
# 25706 25681 25
# 27730 25706 2024
# 28781 27730 1051
# 29881 28781 1100
# 30265 29881 384
# 31158 30265 893
# 32141 31158 983
#
#
# ...
